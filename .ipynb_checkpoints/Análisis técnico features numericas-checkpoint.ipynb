# 2018-08-23  285.9700  286.9400  285.4300  285.7900   49204851
# 2018-08-24  286.4400  287.6700  286.3800  287.5100   57487399
# 2018-08-27  288.8600  289.9000  288.6800  289.7800   57072377
# 2018-08-28  290.3000  290.4175  289.4000  289.9200   46943472
# 2018-08-29  290.1600  291.7400  289.8854  291.4800   61485514
# 2018-08-30  290.9400  291.3600  289.6300  290.3000   61229501
# 2018-08-31  289.8400  290.8100  289.2900  290.3100   66140838
# 2018-09-04  289.8400  290.2100  288.6800  289.8100   57594367
# 2018-09-05  289.4100  289.6400  287.8900  289.0300   72452437
# 2018-09-06  289.1500  289.4900  287.0000  288.1600   65909863
# 2018-09-07  286.9800  288.7000  286.7100  287.6000   73524824
# 2018-09-10  288.7400  289.0400  287.8800  288.1000   50191113
# 2018-09-11  287.3700  289.5500  286.9750  289.0500   50530492
# 2018-09-12  289.0600  289.8000  288.2300  289.1200   59810758
# 2018-09-13  290.3200  291.0384  289.9950  290.8300   51034222
# 2018-09-14  291.0600  291.2700  290.0000  290.8800   55079875
#
# [178 rows x 5 columns]

# %%
df.to_csv("~/Data/{}.csv".format(symbol))

# %%
##Visualize what was collected with matplotlib
# select only close column

close = df[['close']]
# rename the column with symbole name
close = close.rename(columns={'close': symbol})
ax = close.plot(title='symbol')
ax.set_xlabel('date')
ax.set_ylabel('close price')
ax.grid()
plt.show()

# %%
# read csv file, use date as index and read close as a column
df = pd.read_csv('~/Data/{}.csv'.format(symbol), index_col='date',
                 parse_dates=True, usecols=['date', 'close'],
                 na_values='nan')
# rename the column header with symbol name
df = df.rename(columns={'close': symbol})
df.dropna(inplace=True)

# calculate Simple Moving Average with 20 days window
sma = df.rolling(window=20).mean()

# calculate the standar deviation
rstd = df.rolling(window=20).std()

upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
middle_band= sma+ rstd
middle_band = middle_band.rename(columns={symbol: '+1'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})
middlelower_band=sma- rstd
middlelower_band = middlelower_band.rename(columns={symbol: '-1'})


df = df.join(upper_band).join(lower_band).join(middle_band).join(middlelower_band)
ax = df.plot(title='{} Price and BB'.format(symbol))
ax.fill_between(df.index, lower_band['lower'], upper_band['upper'], color='#ADCCFF', alpha='0.4')
ax.set_xlabel('date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()

# %%
start = '2018-01-01'
end = '2018-09-17'
dates = pd.date_range(start, end)

# %%
df1=pd.DataFrame(index=dates)

# %%
spy=pd.read_csv('Data/SPY.csv', index_col='date',parse_dates=True, usecols=['date', 'close'],
                 na_values=['nan'])
spy=spy.rename(columns={'close': symbol})
print(spy)
# Out:
#                  SPY
# date
# 2018-01-02  266.5018
# 2018-01-03  268.1875
# 2018-01-04  269.3178
# 2018-01-05  271.1126
# 2018-01-08  271.6083
# 2018-01-09  272.2231
# 2018-01-10  271.8067
# 2018-01-11  273.7898
# 2018-01-12  275.5746
# 2018-01-16  274.6326
# 2018-01-17  277.2503
# 2018-01-18  276.7843
# 2018-01-19  278.0436
# 2018-01-22  280.3043
# 2018-01-23  280.8993
# 2018-01-24  280.7902
# 2018-01-25  280.9092
# 2018-01-26  284.1615
# 2018-01-29  282.2775
# 2018-01-30  279.3822
# 2018-01-31  279.5210
# 2018-02-01  279.2037
# 2018-02-02  273.1254
# 2018-02-05  261.7026
# 2018-02-06  266.8588
# 2018-02-07  265.4111
# 2018-02-08  255.4558
# 2018-02-09  259.2932
# 2018-02-12  263.1007
# 2018-02-13  263.7552
# ...              ...
# 2018-08-03  283.6000
# 2018-08-06  284.6400
# 2018-08-07  285.5800
# 2018-08-08  285.4600
# 2018-08-09  285.0700
# 2018-08-10  283.1600
# 2018-08-13  282.1000
# 2018-08-14  283.9000
# 2018-08-15  281.7800
# 2018-08-16  284.0600
# 2018-08-17  285.0600
# 2018-08-20  285.6700
# 2018-08-21  286.3400
# 2018-08-22  286.1700
# 2018-08-23  285.7900
# 2018-08-24  287.5100
# 2018-08-27  289.7800
# 2018-08-28  289.9200
# 2018-08-29  291.4800
# 2018-08-30  290.3000
# 2018-08-31  290.3100
# 2018-09-04  289.8100
# 2018-09-05  289.0300
# 2018-09-06  288.1600
# 2018-09-07  287.6000
# 2018-09-10  288.1000
# 2018-09-11  289.0500
# 2018-09-12  289.1200
# 2018-09-13  290.8300
# 2018-09-14  290.8800
#
# [178 rows x 1 columns]

# %%
#join the two dframes
df1=df1.join(spy)
#saco los nulls, de los dias que no se opero
#df1.join(spy, how="inner")
df1=df1.dropna()
print(df1)
# Out:
#                close
# 2018-01-02  266.5018
# 2018-01-03  268.1875
# 2018-01-04  269.3178
# 2018-01-05  271.1126
# 2018-01-08  271.6083
# 2018-01-09  272.2231
# 2018-01-10  271.8067
# 2018-01-11  273.7898
# 2018-01-12  275.5746
# 2018-01-16  274.6326
# 2018-01-17  277.2503
# 2018-01-18  276.7843
# 2018-01-19  278.0436
# 2018-01-22  280.3043
# 2018-01-23  280.8993
# 2018-01-24  280.7902
# 2018-01-25  280.9092
# 2018-01-26  284.1615
# 2018-01-29  282.2775
# 2018-01-30  279.3822
# 2018-01-31  279.5210
# 2018-02-01  279.2037
# 2018-02-02  273.1254
# 2018-02-05  261.7026
# 2018-02-06  266.8588
# 2018-02-07  265.4111
# 2018-02-08  255.4558
# 2018-02-09  259.2932
# 2018-02-12  263.1007
# 2018-02-13  263.7552
# ...              ...
# 2018-08-03  283.6000
# 2018-08-06  284.6400
# 2018-08-07  285.5800
# 2018-08-08  285.4600
# 2018-08-09  285.0700
# 2018-08-10  283.1600
# 2018-08-13  282.1000
# 2018-08-14  283.9000
# 2018-08-15  281.7800
# 2018-08-16  284.0600
# 2018-08-17  285.0600
# 2018-08-20  285.6700
# 2018-08-21  286.3400
# 2018-08-22  286.1700
# 2018-08-23  285.7900
# 2018-08-24  287.5100
# 2018-08-27  289.7800
# 2018-08-28  289.9200
# 2018-08-29  291.4800
# 2018-08-30  290.3000
# 2018-08-31  290.3100
# 2018-09-04  289.8100
# 2018-09-05  289.0300
# 2018-09-06  288.1600
# 2018-09-07  287.6000
# 2018-09-10  288.1000
# 2018-09-11  289.0500
# 2018-09-12  289.1200
# 2018-09-13  290.8300
# 2018-09-14  290.8800
#
# [178 rows x 1 columns]

# %%
df1.join(spy, how="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-47d70ef850b5> in <module>()
# ----> 1 df1.join(spy, how="inner")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6324         # For SparseDataFrame's benefit
#    6325         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6326                                  rsuffix=rsuffix, sort=sort)
#    6327
#    6328     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6339             return merge(self, other, left_on=on, how=how,
#    6340                          left_index=on is None, right_index=True,
# -> 6341                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6342         else:
#    6343             if on is not None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          copy=copy, indicator=indicator,
#      60                          validate=validate)
# ---> 61     return op.get_result()
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     571
#     572         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 573                                                      rdata.items, rsuf)
#     574
#     575         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5242         if not lsuffix and not rsuffix:
#    5243             raise ValueError('columns overlap but no suffix specified: '
# -> 5244                              '{rename}'.format(rename=to_rename))
#    5245
#    5246         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['close'], dtype='object')
